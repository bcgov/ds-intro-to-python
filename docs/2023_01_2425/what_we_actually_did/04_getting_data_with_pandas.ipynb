# %%
import pandas as pd

# %%
series_x = pd.Series(
    [1,2,3]
)

# %%
series_x
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
series_y = pd.Series([1, 2.0, 3.14])
series_y
# Out:
# 0    1.00
# 1    2.00
# 2    3.14
# dtype: float64

# %%
series_z = pd.Series(['settlers', 'of', 'catan'])
series_z
# Out:
# 0    settlers
# 1          of
# 2       catan
# dtype: object

# %%
series_mixed = pd.Series( [1, 1.0, 'one'] )
series_mixed
# Out:
# 0      1
# 1    1.0
# 2    one
# dtype: object

# %%
series_y
# Out:
# 0    1.00
# 1    2.00
# 2    3.14
# dtype: float64

# %%
series_y.astype(int)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int32

# %%
series_y.astype(bool)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
series_y.astype(str)
# Out:
# 0     1.0
# 1     2.0
# 2    3.14
# dtype: object

# %%
series_y.astype('string')
# Out:
# 0     1.0
# 1     2.0
# 2    3.14
# dtype: string

# %%
series_a = pd.Series([2,4,6])
series_a
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
series_a.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
series_a.index = ['a', 'b', 'c']
series_a
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
series_b = series_a.reindex(['d', 'c', 'b', 'a'])
series_b
# Out:
# d    NaN
# c    6.0
# b    4.0
# a    2.0
# dtype: float64

# %%
series_b.astype('Int64')
# Out:
# d    <NA>
# c       6
# b       4
# a       2
# dtype: Int64

# %%
df = pd.read_csv('../data/gapfinder.csv')

# %%
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.columns = [
    'country', 'year', 'pop', 'continent', 'life expectancy', 'gdpPercap'
]

# %%
df
# Out:
#           country  year         pop continent  life expectancy   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia           28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia           30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia           31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia           34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia           36.088  739.981106
# ...           ...   ...         ...       ...              ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa           62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa           60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa           46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa           39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa           43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['life expectancy']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life expectancy, Length: 1704, dtype: float64

# %%
df.life expectancy
# Out:
#   Input In [15]
#     df.life expectancy
#             ^
# SyntaxError: invalid syntax

# %%
df.columns = [
    'country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
]

# %%
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df_challenge = pd.read_csv(
    '../data/gapfinder.csv',
    index_col = 'country',
    usecols = ['year', 'continent', 'pop', 'country']
)
df_challenge
# Out:
#              year         pop continent
# country
# Afghanistan  1952   8425333.0      Asia
# Afghanistan  1957   9240934.0      Asia
# Afghanistan  1962  10267083.0      Asia
# Afghanistan  1967  11537966.0      Asia
# Afghanistan  1972  13079460.0      Asia
# ...           ...         ...       ...
# Zimbabwe     1987   9216418.0    Africa
# Zimbabwe     1992  10704340.0    Africa
# Zimbabwe     1997  11404948.0    Africa
# Zimbabwe     2002  11926563.0    Africa
# Zimbabwe     2007  12311143.0    Africa
#
# [1704 rows x 3 columns]

# %%
df_challenge.year
# Out:
# country
# Afghanistan    1952
# Afghanistan    1957
# Afghanistan    1962
# Afghanistan    1967
# Afghanistan    1972
#                ...
# Zimbabwe       1987
# Zimbabwe       1992
# Zimbabwe       1997
# Zimbabwe       2002
# Zimbabwe       2007
# Name: year, Length: 1704, dtype: int64

# %%
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439
# 7  Afghanistan  1987  13867957.0      Asia   40.822  852.395945
# 8  Afghanistan  1992  16317921.0      Asia   41.674  649.341395
# 9  Afghanistan  1997  22227415.0      Asia   41.763  635.341351

# %%
df.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.sample()
# Out:
#            country  year       pop continent  lifeExp   gdpPercap
# 624  Guinea-Bissau  1952  580653.0    Africa     32.5  299.850319

# %%
df.sample(5)
# Out:
#                        country  year          pop continent  lifeExp  \
# 801                      Japan  1997  125956499.0      Asia   80.690
# 1330                   Senegal  2002   10870037.0    Africa   61.600
# 1497                     Syria  1997   15081016.0      Asia   71.527
# 261   Central African Republic  1997    3696513.0    Africa   46.066
# 1477               Switzerland  1957    5126000.0    Europe   70.560
#
#          gdpPercap
# 801   28816.584990
# 1330   1519.635262
# 1497   4014.238972
# 261     740.506332
# 1477  17909.489730

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.country.value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df.sample(1000).describe()
# Out:
#               year           pop      lifeExp      gdpPercap
# count  1000.000000  1.000000e+03  1000.000000    1000.000000
# mean   1979.455000  2.863866e+07    59.605533    7373.549521
# std      17.360858  9.510331e+07    12.923043   10242.443101
# min    1952.000000  6.001100e+04    23.599000     241.165876
# 25%    1962.000000  2.780344e+06    48.422750    1216.123628
# 50%    1982.000000  6.975320e+06    60.465500    3345.489908
# 75%    1992.000000  1.964891e+07    70.946000    9328.414763
# max    2007.000000  1.164970e+09    82.000000  113523.132900

# %%
df_stats = df.describe()
df_stats
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df_stats.to_csv('../analysis/gapfinder_stats.csv')

# %%
df_stats.to_csv(
    '../analysis/gapfinder_with_index.csv',
    columns = ['pop', 'lifeExp'],
    index = True
)

# %%
df_stats.to_csv(
    '../analysis/gapfinder_no_index.csv',
    columns = ['pop', 'lifeExp'],
    index = False
)

# %%
# ?df_stats.to_csv
# Out:
# Signature:
# df_stats.to_csv(
#     path_or_buf: 'FilePath | WriteBuffer[bytes] | WriteBuffer[str] | None' = None,
#     sep: 'str' = ',',
#     na_rep: 'str' = '',
#     float_format: 'str | None' = None,
#     columns: 'Sequence[Hashable] | None' = None,
#     header: 'bool_t | list[str]' = True,
#     index: 'bool_t' = True,
#     index_label: 'IndexLabel | None' = None,
#     mode: 'str' = 'w',
#     encoding: 'str | None' = None,
#     compression: 'CompressionOptions' = 'infer',
#     quoting: 'int | None' = None,
#     quotechar: 'str' = '"',
#     line_terminator: 'str | None' = None,
#     chunksize: 'int | None' = None,
#     date_format: 'str | None' = None,
#     doublequote: 'bool_t' = True,
#     escapechar: 'str | None' = None,
#     decimal: 'str' = '.',
#     errors: 'str' = 'strict',
#     storage_options: 'StorageOptions' = None,
# ) -> 'str | None'
# Docstring:
# Write object to a comma-separated values (csv) file.
#
# Parameters
# ----------
# ...
